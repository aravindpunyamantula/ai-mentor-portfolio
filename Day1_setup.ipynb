# %% [markdown]
# <a href="https://colab.research.google.com/github/aravindpunyamantula/ai-mentor-portfolio/blob/main/Day1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Enter you key')
# Out:
# Enter you key··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])
resp = client.models.generate_content(
model='gemini-2.5-flash',
contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid is a hierarchical model illustrating the range of expertise needed for successful AI implementation, from technical foundations to strategic and ethical considerations:
#
# *   **Layer 1 & 2: Foundational Technical Skills:** Encompasses data management, infrastructure, and core machine learning algorithm development and model building.
# *   **Layer 3: AI Application & Product Development:** Focuses on leveraging foundational skills to design, build, and deploy practical AI solutions and products.
# *   **Layer 4: Business Integration & Strategy:** Involves strategic thinking to integrate AI into business processes, drive innovation, and formulate organizational AI strategies.
# *   **Layer 5: Ethical & Societal Impact:** The apex, requiring critical understanding and guidance on AI's ethical implications, fairness, governance, and broader societal influence.
